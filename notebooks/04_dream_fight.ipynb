# %% [markdown]
# # 04 - Dream Fight
#
# This notebook predicts and visualizes a hypothetical GSP vs McGregor matchup.

# %%
import pandas as pd
import matplotlib.pyplot as plt

print('Dream fight notebook ready.')
