# %% [markdown]
# # 03 - Model Training
#
# This notebook compares models and saves the best-performing version.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

print('Model training notebook ready.')
