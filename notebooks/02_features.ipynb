# %% [markdown]
# # 02 - Feature Engineering
#
# This notebook is used to build pre-fight features and validate them before model training.

# %%
import pandas as pd

print('Feature notebook ready.')
