# %% [markdown]
# # 01 - Explore
#
# This notebook is for the initial data review: file inspection, schema checks, value distributions, and missing data analysis.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')

print('Notebook ready for exploration.')
